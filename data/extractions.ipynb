# %% [markdown]
# # Tabela Periódica
#
# Aqui é só um demonstrativo da base!

# %%
import pandas as pd

df = pd.read_csv(r'elementdatavalues.csv')
display(df)
# Out:
#             Name Symbol  Atomic_Number  Atomic_Weight    Density  \
# 0       Hydrogen      H              1       1.007940     0.0899
# 1         Helium     He              2       4.002602     0.1785
# 2        Lithium     Li              3       6.941000   535.0000
# 3      Beryllium     Be              4       9.012182  1848.0000
# 4          Boron      B              5      10.811000  2460.0000
# ..           ...    ...            ...            ...        ...
# 113  Ununquadium    Uuq            114     289.000000        NaN
# 114  Ununpentium    Uup            115     288.000000        NaN
# 115   Ununhexium    Uuh            116     292.000000        NaN
# 116  Ununseptium    Uus            117            NaN        NaN
# 117   Ununoctium    Uuo            118     294.000000        NaN
#
#      Melting_Point  Boiling_Point  Phase  Absolute_Melting_Point  \
# 0            14.01          20.28    Gas                   14.01
# ...
